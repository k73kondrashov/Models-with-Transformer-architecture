# %% [markdown]
# # Import and constans

# %%
from tensorflow.keras import layers
from tensorflow import keras

import matplotlib.pyplot as plt
import tensorflow_addons as tfa
import tensorflow as tf
import numpy as np

# %%
positional_emb = True
conv_layers = 2
projection_dim = 128

num_heads = 2
transformer_units = [
    projection_dim,
    projection_dim,
]
transformer_layers = 2
stochastic_depth_rate = 0.1

learning_rate = 0.001
weight_decay = 0.0001
batch_size = 128
num_epochs = 30
image_size = 32

# %% [markdown]
# # Load Data

# %%
num_classes = 10
input_shape = (32, 32, 3)

(x_train, y_train), (x_test, y_test) = keras.datasets.cifar10.load_data()

x_train = x_train / 255.0
x_test = x_test / 255.0

y_train = keras.utils.to_categorical(y_train, num_classes)
y_test = keras.utils.to_categorical(y_test, num_classes)

print(f"x_train shape: {x_train.shape} - y_train shape: {y_train.shape}")
print(f"x_test shape: {x_test.shape} - y_test shape: {y_test.shape}")
# Out:
# x_train shape: (50000, 32, 32, 3) - y_train shape: (50000, 10)
# x_test shape: (10000, 32, 32, 3) - y_test shape: (10000, 10)

# %% [markdown]
# # Build model

# %%
class CCTTokenizer(layers.Layer):
    def __init__(
        self,
        kernel_size=3,
        stride=1,
        padding=1,
        pooling_kernel_size=3,
        pooling_stride=2,
        num_conv_layers=conv_layers,
        num_output_channels=[64, 128],
        positional_emb=positional_emb,
        **kwargs,
    ):
        super(CCTTokenizer, self).__init__(**kwargs)

        # This is our tokenizer.
        self.conv_model = keras.Sequential()
        for i in range(num_conv_layers):
            self.conv_model.add(
                layers.Conv2D(
                    num_output_channels[i],
                    kernel_size,
                    stride,
                    padding="valid",
                    use_bias=False,
                    activation="relu",
                    kernel_initializer="he_normal",
                )
            )
            self.conv_model.add(layers.ZeroPadding2D(padding))
            self.conv_model.add(
                layers.MaxPool2D(pooling_kernel_size, pooling_stride, "same")
            )

        self.positional_emb = positional_emb
        
    def call(self, images):
        outputs = self.conv_model(images)
        # After passing the images through our mini-network the spatial dimensions
        # are flattened to form sequences.
        reshaped = tf.reshape(
            outputs,
            (-1, tf.shape(outputs)[1] * tf.shape(outputs)[2], tf.shape(outputs)[-1]),
        )
        return reshaped
    
    def positional_embedding(self, image_size):
        # Positional embeddings are optional in CCT. Here, we calculate
        # the number of sequences and initialize an `Embedding` layer to
        # compute the positional embeddings later.
        if self.positional_emb:
            dummy_inputs = tf.ones((1, image_size, image_size, 3))
            dummy_outputs = self.call(dummy_inputs)
            sequence_length = tf.shape(dummy_outputs)[1]
            projection_dim = tf.shape(dummy_outputs)[-1]

            embed_layer = layers.Embedding(
                input_dim=sequence_length, output_dim=projection_dim
            )
            return embed_layer, sequence_length
        else:
            return None

# %%
class StochasticDepth(layers.Layer):
    def __init__(self, drop_prop, **kwargs):
        super(StochasticDepth, self).__init__(**kwargs)
        self.drop_prob = drop_prop

    def call(self, x, training=None):
        if training:
            keep_prob = 1 - self.drop_prob
            shape = (tf.shape(x)[0],) + (1,) * (len(tf.shape(x)) - 1)
            random_tensor = keep_prob + tf.random.uniform(shape, 0, 1)
            random_tensor = tf.floor(random_tensor)
            return (x / keep_prob) * random_tensor
        return x

# %%
def mlp(x, hidden_units, dropout_rate):
    for units in hidden_units:
        x = layers.Dense(units, activation=tf.nn.gelu)(x)
        x = layers.Dropout(dropout_rate)(x)
    return x

# %%
# Note the rescaling layer. These layers have pre-defined inference behavior.
data_augmentation = keras.Sequential(
    [
        layers.Rescaling(scale=1.0 / 255),
        layers.RandomCrop(image_size, image_size),
        layers.RandomFlip("horizontal"),
    ],
    name="data_augmentation",
)

# %%
def create_cct_model(
    image_size=image_size,
    input_shape=input_shape,
    num_heads=num_heads,
    projection_dim=projection_dim,
    transformer_units=transformer_units,
):

    inputs = layers.Input(input_shape)

    # Augment data.
    augmented = data_augmentation(inputs)

    # Encode patches.
    cct_tokenizer = CCTTokenizer()
    encoded_patches = cct_tokenizer(augmented)

    # Apply positional embedding.
    if positional_emb:
        pos_embed, seq_length = cct_tokenizer.positional_embedding(image_size)
        positions = tf.range(start=0, limit=seq_length, delta=1)
        position_embeddings = pos_embed(positions)
        encoded_patches += position_embeddings

    # Calculate Stochastic Depth probabilities.
    dpr = [x for x in np.linspace(0, stochastic_depth_rate, transformer_layers)]

    # Create multiple layers of the Transformer block.
    for i in range(transformer_layers):
        # Layer normalization 1.
        x1 = layers.LayerNormalization(epsilon=1e-5)(encoded_patches)

        # Create a multi-head attention layer.
        attention_output = layers.MultiHeadAttention(
            num_heads=num_heads, key_dim=projection_dim, dropout=0.1
        )(x1, x1)

        # Skip connection 1.
        attention_output = StochasticDepth(dpr[i])(attention_output)
        x2 = layers.Add()([attention_output, encoded_patches])

        # Layer normalization 2.
        x3 = layers.LayerNormalization(epsilon=1e-5)(x2)

        # MLP.
        x3 = mlp(x3, hidden_units=transformer_units, dropout_rate=0.1)

        # Skip connection 2.
        x3 = StochasticDepth(dpr[i])(x3)
        encoded_patches = layers.Add()([x3, x2])

    # Apply sequence pooling.
    representation = layers.LayerNormalization(epsilon=1e-5)(encoded_patches)
    attention_weights = tf.nn.softmax(layers.Dense(1)(representation), axis=1)
    weighted_representation = tf.matmul(
        attention_weights, representation, transpose_a=True
    )
    weighted_representation = tf.squeeze(weighted_representation, -2)

    # Classify outputs.
    logits = layers.Dense(num_classes)(weighted_representation)
    # Create the Keras model.
    model = keras.Model(inputs=inputs, outputs=logits)
    return model

# %%
model = create_cct_model()
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 32, 32, 3)]  0           []
#
#  data_augmentation (Sequential)  (None, 32, 32, 3)   0           ['input_1[0][0]']
#
#  cct_tokenizer (CCTTokenizer)   (None, 64, 128)      75456       ['data_augmentation[0][0]']
#
#  tf.__operators__.add (TFOpLamb  (None, 64, 128)     0           ['cct_tokenizer[0][0]']
#  da)
#
#  layer_normalization (LayerNorm  (None, 64, 128)     256         ['tf.__operators__.add[0][0]']
#  alization)
#
#  multi_head_attention (MultiHea  (None, 64, 128)     131968      ['layer_normalization[0][0]',
#  dAttention)                                                      'layer_normalization[0][0]']
#
#  stochastic_depth (StochasticDe  (None, 64, 128)     0           ['multi_head_attention[0][0]']
#  pth)
#
#  add (Add)                      (None, 64, 128)      0           ['stochastic_depth[0][0]',
#                                                                   'tf.__operators__.add[0][0]']
#
#  layer_normalization_1 (LayerNo  (None, 64, 128)     256         ['add[0][0]']
#  rmalization)
#
#  dense (Dense)                  (None, 64, 128)      16512       ['layer_normalization_1[0][0]']
#
#  dropout (Dropout)              (None, 64, 128)      0           ['dense[0][0]']
#
#  dense_1 (Dense)                (None, 64, 128)      16512       ['dropout[0][0]']
#
#  dropout_1 (Dropout)            (None, 64, 128)      0           ['dense_1[0][0]']
#
#  stochastic_depth_1 (Stochastic  (None, 64, 128)     0           ['dropout_1[0][0]']
#  Depth)
#
#  add_1 (Add)                    (None, 64, 128)      0           ['stochastic_depth_1[0][0]',
#                                                                   'add[0][0]']
#
#  layer_normalization_2 (LayerNo  (None, 64, 128)     256         ['add_1[0][0]']
#  rmalization)
#
#  multi_head_attention_1 (MultiH  (None, 64, 128)     131968      ['layer_normalization_2[0][0]',
#  eadAttention)                                                    'layer_normalization_2[0][0]']
#
#  stochastic_depth_2 (Stochastic  (None, 64, 128)     0           ['multi_head_attention_1[0][0]']
#  Depth)
#
#  add_2 (Add)                    (None, 64, 128)      0           ['stochastic_depth_2[0][0]',
#                                                                   'add_1[0][0]']
#
#  layer_normalization_3 (LayerNo  (None, 64, 128)     256         ['add_2[0][0]']
#  rmalization)
#
#  dense_2 (Dense)                (None, 64, 128)      16512       ['layer_normalization_3[0][0]']
#
#  dropout_2 (Dropout)            (None, 64, 128)      0           ['dense_2[0][0]']
#
#  dense_3 (Dense)                (None, 64, 128)      16512       ['dropout_2[0][0]']
#
#  dropout_3 (Dropout)            (None, 64, 128)      0           ['dense_3[0][0]']
#
#  stochastic_depth_3 (Stochastic  (None, 64, 128)     0           ['dropout_3[0][0]']
#  Depth)
#
#  add_3 (Add)                    (None, 64, 128)      0           ['stochastic_depth_3[0][0]',
#                                                                   'add_2[0][0]']
#
#  layer_normalization_4 (LayerNo  (None, 64, 128)     256         ['add_3[0][0]']
#  rmalization)
#
#  dense_4 (Dense)                (None, 64, 1)        129         ['layer_normalization_4[0][0]']
#
#  tf.nn.softmax (TFOpLambda)     (None, 64, 1)        0           ['dense_4[0][0]']
#
#  tf.linalg.matmul (TFOpLambda)  (None, 1, 128)       0           ['tf.nn.softmax[0][0]',
#                                                                   'layer_normalization_4[0][0]']
#
#  tf.compat.v1.squeeze (TFOpLamb  (None, 128)         0           ['tf.linalg.matmul[0][0]']
#  da)
#
#  dense_5 (Dense)                (None, 10)           1290        ['tf.compat.v1.squeeze[0][0]']
#
# ==================================================================================================
# Total params: 408,139
# Trainable params: 408,139
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %% [markdown]
# # Train model

# %%
def run_experiment(model):
    optimizer = tfa.optimizers.AdamW(learning_rate=0.001, weight_decay=0.0001)

    model.compile(
        optimizer=optimizer,
        loss=keras.losses.CategoricalCrossentropy(from_logits=True),
        metrics=[
            'accuracy',
            keras.metrics.TopKCategoricalAccuracy(5, name="top-5-accuracy"),
        ],
    )

    checkpoint_filepath = "tmp/checkpoint"
    checkpoint_callback = keras.callbacks.ModelCheckpoint(
        checkpoint_filepath,
        monitor="val_accuracy",
        save_best_only=True,
        save_weights_only=True,
    )

    history = model.fit(
        x=x_train,
        y=y_train,
        batch_size=batch_size,
        epochs=num_epochs,
        validation_split=0.1,
        callbacks=[checkpoint_callback],
    )

    model.load_weights(checkpoint_filepath)
    _, accuracy, top_5_accuracy = model.evaluate(x_test, y_test)
    print(f"Test accuracy: {round(accuracy * 100, 2)}%")
    print(f"Test top 5 accuracy: {round(top_5_accuracy * 100, 2)}%")

    return history


cct_model = create_cct_model()
history = run_experiment(cct_model)
# Out:
# Epoch 1/30
# 352/352 [==============================] - 34s 88ms/step - loss: 1.9205 - accuracy: 0.2681 - top-5-accuracy: 0.7972 - val_loss: 1.6574 - val_accuracy: 0.3762 - val_top-5-accuracy: 0.8970
# Epoch 2/30
# 352/352 [==============================] - 30s 85ms/step - loss: 1.5568 - accuracy: 0.4128 - top-5-accuracy: 0.9089 - val_loss: 1.4056 - val_accuracy: 0.4808 - val_top-5-accuracy: 0.9412
# Epoch 3/30
# 352/352 [==============================] - 30s 85ms/step - loss: 1.3561 - accuracy: 0.5027 - top-5-accuracy: 0.9367 - val_loss: 1.2624 - val_accuracy: 0.5374 - val_top-5-accuracy: 0.9522
# Epoch 4/30
# 352/352 [==============================] - 30s 85ms/step - loss: 1.2763 - accuracy: 0.5343 - top-5-accuracy: 0.9466 - val_loss: 1.2682 - val_accuracy: 0.5584 - val_top-5-accuracy: 0.9530
# Epoch 5/30
# 352/352 [==============================] - 30s 85ms/step - loss: 1.2013 - accuracy: 0.5644 - top-5-accuracy: 0.9531 - val_loss: 1.1387 - val_accuracy: 0.5984 - val_top-5-accuracy: 0.9592
# Epoch 6/30
# 352/352 [==============================] - 30s 85ms/step - loss: 1.1430 - accuracy: 0.5883 - top-5-accuracy: 0.9591 - val_loss: 1.0752 - val_accuracy: 0.6158 - val_top-5-accuracy: 0.9664
# Epoch 7/30
# 352/352 [==============================] - 30s 85ms/step - loss: 1.1050 - accuracy: 0.6018 - top-5-accuracy: 0.9623 - val_loss: 1.0608 - val_accuracy: 0.6172 - val_top-5-accuracy: 0.9654
# Epoch 8/30
# 352/352 [==============================] - 30s 85ms/step - loss: 1.0698 - accuracy: 0.6130 - top-5-accuracy: 0.9651 - val_loss: 0.9992 - val_accuracy: 0.6376 - val_top-5-accuracy: 0.9704
# Epoch 9/30
# 352/352 [==============================] - 30s 86ms/step - loss: 1.0390 - accuracy: 0.6283 - top-5-accuracy: 0.9678 - val_loss: 1.0184 - val_accuracy: 0.6438 - val_top-5-accuracy: 0.9682
# Epoch 10/30
# 352/352 [==============================] - 30s 86ms/step - loss: 1.0112 - accuracy: 0.6386 - top-5-accuracy: 0.9684 - val_loss: 0.9888 - val_accuracy: 0.6496 - val_top-5-accuracy: 0.9712
# Epoch 11/30
# 352/352 [==============================] - 30s 86ms/step - loss: 0.9863 - accuracy: 0.6478 - top-5-accuracy: 0.9701 - val_loss: 0.9516 - val_accuracy: 0.6622 - val_top-5-accuracy: 0.9702
# Epoch 12/30
# 352/352 [==============================] - 30s 86ms/step - loss: 0.9753 - accuracy: 0.6504 - top-5-accuracy: 0.9712 - val_loss: 0.9893 - val_accuracy: 0.6492 - val_top-5-accuracy: 0.9710
# Epoch 13/30
# 352/352 [==============================] - 31s 88ms/step - loss: 0.9576 - accuracy: 0.6575 - top-5-accuracy: 0.9721 - val_loss: 0.9488 - val_accuracy: 0.6628 - val_top-5-accuracy: 0.9760
# Epoch 14/30
# 352/352 [==============================] - 33s 94ms/step - loss: 0.9355 - accuracy: 0.6651 - top-5-accuracy: 0.9738 - val_loss: 0.9255 - val_accuracy: 0.6706 - val_top-5-accuracy: 0.9744
# Epoch 15/30
# 352/352 [==============================] - 32s 90ms/step - loss: 0.9275 - accuracy: 0.6688 - top-5-accuracy: 0.9748 - val_loss: 0.8671 - val_accuracy: 0.6950 - val_top-5-accuracy: 0.9810
# Epoch 16/30
# 352/352 [==============================] - 31s 89ms/step - loss: 0.9029 - accuracy: 0.6784 - top-5-accuracy: 0.9755 - val_loss: 0.8910 - val_accuracy: 0.6806 - val_top-5-accuracy: 0.9758
# Epoch 17/30
# 352/352 [==============================] - 30s 86ms/step - loss: 0.8962 - accuracy: 0.6784 - top-5-accuracy: 0.9768 - val_loss: 0.9072 - val_accuracy: 0.6800 - val_top-5-accuracy: 0.9782
# Epoch 18/30
# 352/352 [==============================] - 30s 86ms/step - loss: 0.8821 - accuracy: 0.6863 - top-5-accuracy: 0.9774 - val_loss: 0.9013 - val_accuracy: 0.6818 - val_top-5-accuracy: 0.9810
# Epoch 19/30
# 352/352 [==============================] - 32s 91ms/step - loss: 0.8692 - accuracy: 0.6906 - top-5-accuracy: 0.9774 - val_loss: 0.8763 - val_accuracy: 0.6942 - val_top-5-accuracy: 0.9784
# Epoch 20/30
# 352/352 [==============================] - 33s 94ms/step - loss: 0.8606 - accuracy: 0.6951 - top-5-accuracy: 0.9781 - val_loss: 0.9148 - val_accuracy: 0.6838 - val_top-5-accuracy: 0.9792
# Epoch 21/30
# 352/352 [==============================] - 30s 85ms/step - loss: 0.8521 - accuracy: 0.6973 - top-5-accuracy: 0.9794 - val_loss: 0.8137 - val_accuracy: 0.7176 - val_top-5-accuracy: 0.9826
# Epoch 22/30
# 352/352 [==============================] - 30s 85ms/step - loss: 0.8321 - accuracy: 0.7041 - top-5-accuracy: 0.9802 - val_loss: 0.8438 - val_accuracy: 0.6970 - val_top-5-accuracy: 0.9782
# Epoch 23/30
# 352/352 [==============================] - 30s 86ms/step - loss: 0.8233 - accuracy: 0.7086 - top-5-accuracy: 0.9810 - val_loss: 0.7881 - val_accuracy: 0.7252 - val_top-5-accuracy: 0.9838
# Epoch 24/30
# 352/352 [==============================] - 30s 85ms/step - loss: 0.8245 - accuracy: 0.7063 - top-5-accuracy: 0.9798 - val_loss: 0.8685 - val_accuracy: 0.6932 - val_top-5-accuracy: 0.9792
# Epoch 25/30
# 352/352 [==============================] - 30s 85ms/step - loss: 0.7974 - accuracy: 0.7168 - top-5-accuracy: 0.9829 - val_loss: 0.7555 - val_accuracy: 0.7356 - val_top-5-accuracy: 0.9846
# Epoch 26/30
# 352/352 [==============================] - 30s 85ms/step - loss: 0.7915 - accuracy: 0.7197 - top-5-accuracy: 0.9828 - val_loss: 0.8223 - val_accuracy: 0.7078 - val_top-5-accuracy: 0.9838
# Epoch 27/30
# 352/352 [==============================] - 30s 85ms/step - loss: 0.7777 - accuracy: 0.7246 - top-5-accuracy: 0.9830 - val_loss: 0.8220 - val_accuracy: 0.7138 - val_top-5-accuracy: 0.9834
# Epoch 28/30
# 352/352 [==============================] - 30s 85ms/step - loss: 0.7706 - accuracy: 0.7285 - top-5-accuracy: 0.9827 - val_loss: 0.7908 - val_accuracy: 0.7280 - val_top-5-accuracy: 0.9808
# Epoch 29/30
# 352/352 [==============================] - 30s 86ms/step - loss: 0.7773 - accuracy: 0.7228 - top-5-accuracy: 0.9829 - val_loss: 0.8561 - val_accuracy: 0.7026 - val_top-5-accuracy: 0.9838
# Epoch 30/30
# 352/352 [==============================] - 30s 86ms/step - loss: 0.7665 - accuracy: 0.7269 - top-5-accuracy: 0.9846 - val_loss: 0.7433 - val_accuracy: 0.7348 - val_top-5-accuracy: 0.9856
# 313/313 [==============================] - 5s 15ms/step - loss: 0.7957 - accuracy: 0.7211 - top-5-accuracy: 0.9832
# Test accuracy: 72.11%
# Test top 5 accuracy: 98.32%

# %% [markdown]
# # Results

# %%
dict_labels = dict(zip(list(range(10)), ['airplane',
                                         'automobile',
                                         'bird',
                                         'cat',
                                         'deer',
                                         'dog',
                                         'frog',
                                         'horse',
                                         'ship',
                                         'truck']))

# %%
predictions = cct_model.predict(x_test)
plt.figure(figsize=(15,15))
for i in range(25):
    n = np.random.choice(x_test.shape[0])
    plt.subplot(5,5,i+1).imshow(x_test[n])
    label = dict_labels[np.argmax(predictions[n])]
    plt.title(label)
